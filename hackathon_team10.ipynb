# %% [markdown]
# <a href="https://colab.research.google.com/github/seungalee/2022_cau_oss_hackathon/blob/main/hackathon_team10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **0. 해커톤 진행 주의사항**
#
# **1)  개발 관련 주의사항**
# *   [1. 초기 환경 설정]은 절대 수정하지 말 것
# *   모든 구현은 [2. 데이터 전처리] 및 [3.모델 생성]에서만 진행
# *   [4. 모델 저장]에서 team_name 변수 변경 (예.`team_name = 'team01'`)
#  *    트레이닝 중간에 checkpoint를 활용하여 모델을 저장한 경우에도 파일 이름 양식 통일 필수
# *   Colab 사용중 실수로 데이터 손실이 발생할 수도 있으니 중간 결과값을 github에 업로드
#  *    "런타임 -> 런타임 연결 해제 및 삭제"은 절대 누르지 말 것 (저장한 모델 데이터가 모두 삭제됨)
#  *    "런타임 -> 런타임 다시시작"은 클라우드 스토리지에 저장된 모델은 유지됨
# *   효율적인 구현 및 테스팅을 위해 GPU 가속 기능 활성화
#  *    "런타임 -> 런타임 유형변경 -> 하드웨어 가속기 -> GPU 설정"
# *   주석을 최대한 자세히 작성
# *   Keras API 관련하여 [Keras Documentation](https://keras.io/) 참조
#
# **2) 제출 관련 주의사항**
# *  제출물
#  *  소스코드 (hackathon_teamXX.ipynb)
#  *  컴파일된 모델 파일 (model_entire_teamXX.h5)
#  *  모델 발표 자료
# * 제출 기한: **오후 6시 (단, 발표자료는 12시)**
# * 제출 방법: [GitHub README](https://github.com/cauosshackathonta/2022_cau_oss_hackathon/) 참조
#
#
# **3) 평가 관련 주의사항**
# *  모델 성능 = 테스트 데이터 셋 분류 정확도
#  *  model.evaluate(x_test, y_test)
# *  제출된 모델들의 테스트 데이터 셋 분류 정확도를 기준으로 수상작 결정
# *  수상 후보들에 대해서는 소스코드를 기반으로 모델 재검증
#
# **4) 수상 실격 사유**
# *  유사한 소스코드가 적발될 경우
# *  Pre-trained 모델을 사용한 경우 (transfer learning 포함)
# *  소스코드와 제출된 모델이 상이한 경우
# *  개발 관련 주의사항을 지키지 않은 경우
#  *  예: [초기 환경 설정]을 수정한 경우
# *  데이터 셋을 변조한 경우
#  *  예. 테스트 데이터 셋을 트레이닝 데이터 셋에 포함하여 모델 생성
# *  주석이 소스코드와 맞지 않거나 미비할 경우

# %% [markdown]
# # **1. 초기 환경 설정**

# %%
from __future__ import absolute_import, division, print_function, unicode_literals, unicode_literals

# tensorflow와 tf.keras 및 관련 라이브러리 임포트
import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np
import matplotlib.pylab as pl

from tensorflow import keras
from keras.utils import np_utils
from keras import datasets, layers, models

# 데이터셋 로드 (MNIST, fashion-MNIST, Kujushiji-MNIST, MNIST_corrupted (test only))
train_ds, test_ds = tfds.load('mnist', split=['train', 'test'], shuffle_files=False, batch_size=-1)

train_ds2, test_ds2 = tfds.load('fashion_mnist', split=['train', 'test'], shuffle_files=False, batch_size=-1)
train_ds2['label'] += 10;
test_ds2['label'] += 10;

train_ds3, test_ds3 = tfds.load('kmnist', split=['train', 'test'], shuffle_files=False, batch_size=-1)
train_ds3['label'] += 20;
test_ds3['label'] += 20;

test_ds4 = tfds.load('mnist_corrupted/zigzag', split='test', shuffle_files=False, batch_size=-1)

# 데이터셋 병합 (training: 180,000개, test: 40,000개)
x_train = np.append(np.append(train_ds['image'], train_ds2['image'], 0), train_ds3['image'], 0);
y_train = np.append(np.append(train_ds['label'], train_ds2['label'], 0), train_ds3['label'], 0);

x_test = np.append(np.append(np.append(test_ds['image'], test_ds2['image'], 0), test_ds3['image'], 0), test_ds4['image'], 0);
y_test = np.append(np.append(np.append(test_ds['label'], test_ds2['label'], 0), test_ds3['label'], 0), test_ds4['label'], 0);

# 분류를 위해 클래스 벡터를 바이너리 매트릭스로 변환
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)

# 총 클래스 개수: 30, 입력 데이터 구조: (28, 28, 1)
num_classes = y_train.shape[1]
input_shape = x_train.shape[1:]
print(num_classes, input_shape)
# Out:
# Downloading and preparing dataset 11.06 MiB (download: 11.06 MiB, generated: 21.00 MiB, total: 32.06 MiB) to ~/tensorflow_datasets/mnist/3.0.1...
# Dl Completed...:   0%|          | 0/4 [00:00<?, ? file/s]
# Dataset mnist downloaded and prepared to ~/tensorflow_datasets/mnist/3.0.1. Subsequent calls will reuse this data.
# Downloading and preparing dataset 29.45 MiB (download: 29.45 MiB, generated: 36.42 MiB, total: 65.87 MiB) to ~/tensorflow_datasets/fashion_mnist/3.0.1...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/60000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/fashion_mnist/3.0.1.incompleteC36CYV/fashion_mnist-train.tfrecord*...:   0%|  …
# Generating test examples...:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/fashion_mnist/3.0.1.incompleteC36CYV/fashion_mnist-test.tfrecord*...:   0%|   …
# Dataset fashion_mnist downloaded and prepared to ~/tensorflow_datasets/fashion_mnist/3.0.1. Subsequent calls will reuse this data.
# Downloading and preparing dataset 20.26 MiB (download: 20.26 MiB, generated: 31.76 MiB, total: 52.02 MiB) to ~/tensorflow_datasets/kmnist/3.0.1...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/60000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/kmnist/3.0.1.incompleteCRD46G/kmnist-train.tfrecord*...:   0%|          | 0/60…
# Generating test examples...:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/kmnist/3.0.1.incompleteCRD46G/kmnist-test.tfrecord*...:   0%|          | 0/100…
# Dataset kmnist downloaded and prepared to ~/tensorflow_datasets/kmnist/3.0.1. Subsequent calls will reuse this data.
# Downloading and preparing dataset 235.23 MiB (download: 235.23 MiB, generated: Unknown size, total: 235.23 MiB) to ~/tensorflow_datasets/mnist_corrupted/zigzag/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/60000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/mnist_corrupted/zigzag/1.0.0.incompleteHU0DCO/mnist_corrupted-train.tfrecord*.…
# Generating test examples...:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/mnist_corrupted/zigzag/1.0.0.incompleteHU0DCO/mnist_corrupted-test.tfrecord*..…
# Dataset mnist_corrupted downloaded and prepared to ~/tensorflow_datasets/mnist_corrupted/zigzag/1.0.0. Subsequent calls will reuse this data.
# 30 (28, 28, 1)

# %% [markdown]
# # **2. 데이터 전처리**

# %%
# 데이터 전처리 (예: normalization)
# 원본 데이터와 전처리 후 데이터를 구분하기 위해, 변수명 x_train_after, x_test_after를 변경하지 말 것
x_train_after = x_train / 255
x_test_after = x_test / 255

# %% [markdown]
# # **3. 모델 생성**

# %%
drop_rate = 0.3
# 순차 모델 생성 (가장 기본구조)
model = keras.Sequential()

# Flatten layer: 28 x 28 x 1 image를 1D vector input으로 변환
model.add(keras.layers.Flatten(input_shape=input_shape))

# 1st hidden layer: fully-connected layer
model.add(keras.layers.Dense(512, activation=tf.nn.relu))
model.add(keras.layers.Dropout(drop_rate))



# 2nd hidden layer: fully-connected layer 
model.add(keras.layers.Dense(256, activation=tf.nn.relu))
model.add(keras.layers.Dropout(drop_rate))


# 3rd hidden layer: fully-connected layer 
model.add(keras.layers.Dense(128, activation=tf.nn.relu))
model.add(keras.layers.Dropout(drop_rate))

# 4th hidden layer: fully-connected layer 
#model.add(keras.layers.Dense(128, activation=tf.nn.relu))
#model.add(keras.layers.Dropout(drop_rate))


# Output layer: fully-connected layer 
model.add(keras.layers.Dense(num_classes, activation=tf.nn.softmax))

# 모델 컴파일
# optimizer: 모델을 업데이트 하는 방식
# loss: 모델의 정확도를 판단하는 방식
# metrics: 트레이닝 및 테스팅 성능 모니터링을 위한 평가지표
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])


# 체크포인트 생성
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath='/content/checkpoint_entire_best.h5', monitor='val_accuracy', verbose=1, save_weight_only=False, save_best_only=True, mode='auto')

# 모델 트레이닝
# batch_size: 전체 데이터셋 중 몇개씩 학습시킬 것인지
# epoch: 학습에 전체 데이터셋이 총 몇번 이용될 것인지
# shuffle: 학습전에 트레이닝 데이터셋을 랜덤하게 섞을 것인지
# validation_data: 중간 성능 검증에 사용할 data set (x_test1_after, x_test2_after, 혹은 둘을 merge해서 사용)
gold=model.fit(x_train_after, y_train, batch_size = 128, epochs = 100, shuffle=True, callbacks=[cp_callback], validation_data=(x_test_after, y_test))

model.summary()
# Out:
# Epoch 1/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 0.6252 - accuracy: 0.8100
# Epoch 1: val_accuracy improved from -inf to 0.81697, saving model to /content/checkpoint_entire_best.h5
# 1407/1407 [==============================] - 12s 8ms/step - loss: 0.6249 - accuracy: 0.8100 - val_loss: 0.6021 - val_accuracy: 0.8170
# Epoch 2/100
# 1400/1407 [============================>.] - ETA: 0s - loss: 0.3366 - accuracy: 0.8926
# Epoch 2: val_accuracy improved from 0.81697 to 0.83695, saving model to /content/checkpoint_entire_best.h5
# 1407/1407 [==============================] - 12s 8ms/step - loss: 0.3366 - accuracy: 0.8925 - val_loss: 0.5754 - val_accuracy: 0.8370
# Epoch 3/100
# 1403/1407 [============================>.] - ETA: 0s - loss: 0.2837 - accuracy: 0.9089
# Epoch 3: val_accuracy improved from 0.83695 to 0.84530, saving model to /content/checkpoint_entire_best.h5
# 1407/1407 [==============================] - 12s 8ms/step - loss: 0.2837 - accuracy: 0.9090 - val_loss: 0.5763 - val_accuracy: 0.8453
# Epoch 4/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.2557 - accuracy: 0.9162
# Epoch 4: val_accuracy did not improve from 0.84530
# 1407/1407 [==============================] - 14s 10ms/step - loss: 0.2557 - accuracy: 0.9162 - val_loss: 0.7386 - val_accuracy: 0.8285
# Epoch 5/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.2348 - accuracy: 0.9219
# Epoch 5: val_accuracy did not improve from 0.84530
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.2349 - accuracy: 0.9219 - val_loss: 0.6359 - val_accuracy: 0.8419
# Epoch 6/100
# 1401/1407 [============================>.] - ETA: 0s - loss: 0.2225 - accuracy: 0.9256
# Epoch 6: val_accuracy improved from 0.84530 to 0.84648, saving model to /content/checkpoint_entire_best.h5
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.2225 - accuracy: 0.9256 - val_loss: 0.6548 - val_accuracy: 0.8465
# Epoch 7/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 0.2137 - accuracy: 0.9292
# Epoch 7: val_accuracy did not improve from 0.84648
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.2137 - accuracy: 0.9292 - val_loss: 0.6985 - val_accuracy: 0.8400
# Epoch 8/100
# 1405/1407 [============================>.] - ETA: 0s - loss: 0.2025 - accuracy: 0.9322
# Epoch 8: val_accuracy improved from 0.84648 to 0.84957, saving model to /content/checkpoint_entire_best.h5
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.2025 - accuracy: 0.9322 - val_loss: 0.6944 - val_accuracy: 0.8496
# Epoch 9/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 0.1980 - accuracy: 0.9338
# Epoch 9: val_accuracy did not improve from 0.84957
# 1407/1407 [==============================] - 12s 9ms/step - loss: 0.1980 - accuracy: 0.9339 - val_loss: 0.7187 - val_accuracy: 0.8444
# Epoch 10/100
# 1403/1407 [============================>.] - ETA: 0s - loss: 0.1880 - accuracy: 0.9365
# Epoch 10: val_accuracy did not improve from 0.84957
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1879 - accuracy: 0.9365 - val_loss: 0.7267 - val_accuracy: 0.8482
# Epoch 11/100
# 1403/1407 [============================>.] - ETA: 0s - loss: 0.1860 - accuracy: 0.9373
# Epoch 11: val_accuracy did not improve from 0.84957
# 1407/1407 [==============================] - 14s 10ms/step - loss: 0.1859 - accuracy: 0.9373 - val_loss: 0.8865 - val_accuracy: 0.8355
# Epoch 12/100
# 1401/1407 [============================>.] - ETA: 0s - loss: 0.1798 - accuracy: 0.9397
# Epoch 12: val_accuracy did not improve from 0.84957
# 1407/1407 [==============================] - 12s 9ms/step - loss: 0.1800 - accuracy: 0.9396 - val_loss: 0.8472 - val_accuracy: 0.8375
# Epoch 13/100
# 1403/1407 [============================>.] - ETA: 0s - loss: 0.1765 - accuracy: 0.9402
# Epoch 13: val_accuracy did not improve from 0.84957
# 1407/1407 [==============================] - 12s 9ms/step - loss: 0.1765 - accuracy: 0.9402 - val_loss: 0.7608 - val_accuracy: 0.8450
# Epoch 14/100
# 1407/1407 [==============================] - ETA: 0s - loss: 0.1708 - accuracy: 0.9417
# Epoch 14: val_accuracy improved from 0.84957 to 0.85558, saving model to /content/checkpoint_entire_best.h5
# 1407/1407 [==============================] - 12s 9ms/step - loss: 0.1708 - accuracy: 0.9417 - val_loss: 0.7613 - val_accuracy: 0.8556
# Epoch 15/100
# 1403/1407 [============================>.] - ETA: 0s - loss: 0.1693 - accuracy: 0.9422
# Epoch 15: val_accuracy did not improve from 0.85558
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1692 - accuracy: 0.9422 - val_loss: 0.7750 - val_accuracy: 0.8512
# Epoch 16/100
# 1401/1407 [============================>.] - ETA: 0s - loss: 0.1658 - accuracy: 0.9439
# Epoch 16: val_accuracy did not improve from 0.85558
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1660 - accuracy: 0.9438 - val_loss: 0.7733 - val_accuracy: 0.8512
# Epoch 17/100
# 1407/1407 [==============================] - ETA: 0s - loss: 0.1636 - accuracy: 0.9440
# Epoch 17: val_accuracy did not improve from 0.85558
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1636 - accuracy: 0.9440 - val_loss: 0.8665 - val_accuracy: 0.8471
# Epoch 18/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 0.1607 - accuracy: 0.9450
# Epoch 18: val_accuracy did not improve from 0.85558
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1608 - accuracy: 0.9449 - val_loss: 0.7375 - val_accuracy: 0.8542
# Epoch 19/100
# 1402/1407 [============================>.] - ETA: 0s - loss: 0.1578 - accuracy: 0.9459
# Epoch 19: val_accuracy did not improve from 0.85558
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1576 - accuracy: 0.9460 - val_loss: 0.7987 - val_accuracy: 0.8533
# Epoch 20/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 0.1562 - accuracy: 0.9462
# Epoch 20: val_accuracy did not improve from 0.85558
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1563 - accuracy: 0.9462 - val_loss: 0.9627 - val_accuracy: 0.8430
# Epoch 21/100
# 1407/1407 [==============================] - ETA: 0s - loss: 0.1521 - accuracy: 0.9486
# Epoch 21: val_accuracy improved from 0.85558 to 0.85990, saving model to /content/checkpoint_entire_best.h5
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1521 - accuracy: 0.9486 - val_loss: 0.7329 - val_accuracy: 0.8599
# Epoch 22/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 0.1511 - accuracy: 0.9480
# Epoch 22: val_accuracy did not improve from 0.85990
# 1407/1407 [==============================] - 12s 9ms/step - loss: 0.1510 - accuracy: 0.9480 - val_loss: 0.8521 - val_accuracy: 0.8495
# Epoch 23/100
# 1407/1407 [==============================] - ETA: 0s - loss: 0.1499 - accuracy: 0.9492
# Epoch 23: val_accuracy did not improve from 0.85990
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1499 - accuracy: 0.9492 - val_loss: 0.8553 - val_accuracy: 0.8539
# Epoch 24/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.1489 - accuracy: 0.9492
# Epoch 24: val_accuracy did not improve from 0.85990
# 1407/1407 [==============================] - 12s 9ms/step - loss: 0.1489 - accuracy: 0.9492 - val_loss: 0.9696 - val_accuracy: 0.8477
# Epoch 25/100
# 1403/1407 [============================>.] - ETA: 0s - loss: 0.1460 - accuracy: 0.9499
# Epoch 25: val_accuracy improved from 0.85990 to 0.86198, saving model to /content/checkpoint_entire_best.h5
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1460 - accuracy: 0.9499 - val_loss: 0.7685 - val_accuracy: 0.8620
# Epoch 26/100
# 1401/1407 [============================>.] - ETA: 0s - loss: 0.1445 - accuracy: 0.9505
# Epoch 26: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1444 - accuracy: 0.9506 - val_loss: 0.8909 - val_accuracy: 0.8531
# Epoch 27/100
# 1401/1407 [============================>.] - ETA: 0s - loss: 0.1426 - accuracy: 0.9512
# Epoch 27: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1426 - accuracy: 0.9512 - val_loss: 0.8984 - val_accuracy: 0.8485
# Epoch 28/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.1422 - accuracy: 0.9512
# Epoch 28: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1422 - accuracy: 0.9512 - val_loss: 0.9158 - val_accuracy: 0.8521
# Epoch 29/100
# 1405/1407 [============================>.] - ETA: 0s - loss: 0.1424 - accuracy: 0.9513
# Epoch 29: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1424 - accuracy: 0.9512 - val_loss: 0.9189 - val_accuracy: 0.8547
# Epoch 30/100
# 1401/1407 [============================>.] - ETA: 0s - loss: 0.1379 - accuracy: 0.9524
# Epoch 30: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 12s 9ms/step - loss: 0.1378 - accuracy: 0.9524 - val_loss: 0.8812 - val_accuracy: 0.8561
# Epoch 31/100
# 1405/1407 [============================>.] - ETA: 0s - loss: 0.1394 - accuracy: 0.9521
# Epoch 31: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1394 - accuracy: 0.9521 - val_loss: 0.8961 - val_accuracy: 0.8557
# Epoch 32/100
# 1405/1407 [============================>.] - ETA: 0s - loss: 0.1384 - accuracy: 0.9532
# Epoch 32: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1384 - accuracy: 0.9531 - val_loss: 0.9583 - val_accuracy: 0.8505
# Epoch 33/100
# 1403/1407 [============================>.] - ETA: 0s - loss: 0.1356 - accuracy: 0.9533
# Epoch 33: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 12s 9ms/step - loss: 0.1357 - accuracy: 0.9533 - val_loss: 0.8211 - val_accuracy: 0.8610
# Epoch 34/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.1343 - accuracy: 0.9536
# Epoch 34: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 10ms/step - loss: 0.1343 - accuracy: 0.9536 - val_loss: 0.8332 - val_accuracy: 0.8584
# Epoch 35/100
# 1402/1407 [============================>.] - ETA: 0s - loss: 0.1345 - accuracy: 0.9542
# Epoch 35: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1345 - accuracy: 0.9541 - val_loss: 0.9364 - val_accuracy: 0.8492
# Epoch 36/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.1330 - accuracy: 0.9547
# Epoch 36: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1330 - accuracy: 0.9547 - val_loss: 0.9087 - val_accuracy: 0.8489
# Epoch 37/100
# 1403/1407 [============================>.] - ETA: 0s - loss: 0.1321 - accuracy: 0.9550
# Epoch 37: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1320 - accuracy: 0.9550 - val_loss: 0.9606 - val_accuracy: 0.8504
# Epoch 38/100
# 1405/1407 [============================>.] - ETA: 0s - loss: 0.1301 - accuracy: 0.9556
# Epoch 38: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1301 - accuracy: 0.9556 - val_loss: 0.9045 - val_accuracy: 0.8567
# Epoch 39/100
# 1403/1407 [============================>.] - ETA: 0s - loss: 0.1297 - accuracy: 0.9553
# Epoch 39: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1296 - accuracy: 0.9553 - val_loss: 0.8173 - val_accuracy: 0.8595
# Epoch 40/100
# 1405/1407 [============================>.] - ETA: 0s - loss: 0.1301 - accuracy: 0.9553
# Epoch 40: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1301 - accuracy: 0.9553 - val_loss: 0.8286 - val_accuracy: 0.8571
# Epoch 41/100
# 1402/1407 [============================>.] - ETA: 0s - loss: 0.1296 - accuracy: 0.9560
# Epoch 41: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1295 - accuracy: 0.9561 - val_loss: 0.9374 - val_accuracy: 0.8538
# Epoch 42/100
# 1407/1407 [==============================] - ETA: 0s - loss: 0.1278 - accuracy: 0.9562
# Epoch 42: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1278 - accuracy: 0.9562 - val_loss: 0.8319 - val_accuracy: 0.8600
# Epoch 43/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.1273 - accuracy: 0.9566
# Epoch 43: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1273 - accuracy: 0.9566 - val_loss: 0.9254 - val_accuracy: 0.8507
# Epoch 44/100
# 1402/1407 [============================>.] - ETA: 0s - loss: 0.1275 - accuracy: 0.9561
# Epoch 44: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1274 - accuracy: 0.9562 - val_loss: 1.0283 - val_accuracy: 0.8477
# Epoch 45/100
# 1402/1407 [============================>.] - ETA: 0s - loss: 0.1260 - accuracy: 0.9571
# Epoch 45: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1260 - accuracy: 0.9572 - val_loss: 0.9604 - val_accuracy: 0.8504
# Epoch 46/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 0.1246 - accuracy: 0.9576
# Epoch 46: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1246 - accuracy: 0.9576 - val_loss: 1.0945 - val_accuracy: 0.8509
# Epoch 47/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.1243 - accuracy: 0.9573
# Epoch 47: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1243 - accuracy: 0.9574 - val_loss: 0.9476 - val_accuracy: 0.8554
# Epoch 48/100
# 1403/1407 [============================>.] - ETA: 0s - loss: 0.1229 - accuracy: 0.9578
# Epoch 48: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1229 - accuracy: 0.9578 - val_loss: 1.0911 - val_accuracy: 0.8498
# Epoch 49/100
# 1407/1407 [==============================] - ETA: 0s - loss: 0.1235 - accuracy: 0.9581
# Epoch 49: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1235 - accuracy: 0.9581 - val_loss: 0.8734 - val_accuracy: 0.8560
# Epoch 50/100
# 1403/1407 [============================>.] - ETA: 0s - loss: 0.1241 - accuracy: 0.9576
# Epoch 50: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 14s 10ms/step - loss: 0.1242 - accuracy: 0.9576 - val_loss: 0.9639 - val_accuracy: 0.8493
# Epoch 51/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.1207 - accuracy: 0.9585
# Epoch 51: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1207 - accuracy: 0.9585 - val_loss: 1.0850 - val_accuracy: 0.8499
# Epoch 52/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 0.1209 - accuracy: 0.9594
# Epoch 52: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 12s 9ms/step - loss: 0.1210 - accuracy: 0.9594 - val_loss: 1.0180 - val_accuracy: 0.8539
# Epoch 53/100
# 1401/1407 [============================>.] - ETA: 0s - loss: 0.1222 - accuracy: 0.9586
# Epoch 53: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 12s 9ms/step - loss: 0.1223 - accuracy: 0.9586 - val_loss: 0.9619 - val_accuracy: 0.8549
# Epoch 54/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 0.1186 - accuracy: 0.9593
# Epoch 54: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 12s 9ms/step - loss: 0.1186 - accuracy: 0.9593 - val_loss: 1.0736 - val_accuracy: 0.8574
# Epoch 55/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.1199 - accuracy: 0.9593
# Epoch 55: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 14s 10ms/step - loss: 0.1199 - accuracy: 0.9593 - val_loss: 1.0588 - val_accuracy: 0.8507
# Epoch 56/100
# 1407/1407 [==============================] - ETA: 0s - loss: 0.1170 - accuracy: 0.9598
# Epoch 56: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 12s 9ms/step - loss: 0.1170 - accuracy: 0.9598 - val_loss: 1.0719 - val_accuracy: 0.8508
# Epoch 57/100
# 1403/1407 [============================>.] - ETA: 0s - loss: 0.1172 - accuracy: 0.9600
# Epoch 57: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1171 - accuracy: 0.9600 - val_loss: 1.1012 - val_accuracy: 0.8505
# Epoch 58/100
# 1401/1407 [============================>.] - ETA: 0s - loss: 0.1162 - accuracy: 0.9600
# Epoch 58: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1161 - accuracy: 0.9600 - val_loss: 0.9724 - val_accuracy: 0.8552
# Epoch 59/100
# 1405/1407 [============================>.] - ETA: 0s - loss: 0.1185 - accuracy: 0.9601
# Epoch 59: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1185 - accuracy: 0.9601 - val_loss: 0.9906 - val_accuracy: 0.8551
# Epoch 60/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.1185 - accuracy: 0.9599
# Epoch 60: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1184 - accuracy: 0.9599 - val_loss: 1.0084 - val_accuracy: 0.8522
# Epoch 61/100
# 1405/1407 [============================>.] - ETA: 0s - loss: 0.1180 - accuracy: 0.9599
# Epoch 61: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1180 - accuracy: 0.9600 - val_loss: 1.0201 - val_accuracy: 0.8519
# Epoch 62/100
# 1403/1407 [============================>.] - ETA: 0s - loss: 0.1179 - accuracy: 0.9596
# Epoch 62: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1180 - accuracy: 0.9596 - val_loss: 1.0311 - val_accuracy: 0.8520
# Epoch 63/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.1163 - accuracy: 0.9608
# Epoch 63: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1163 - accuracy: 0.9608 - val_loss: 1.1692 - val_accuracy: 0.8473
# Epoch 64/100
# 1403/1407 [============================>.] - ETA: 0s - loss: 0.1144 - accuracy: 0.9612
# Epoch 64: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1144 - accuracy: 0.9612 - val_loss: 1.0362 - val_accuracy: 0.8509
# Epoch 65/100
# 1402/1407 [============================>.] - ETA: 0s - loss: 0.1148 - accuracy: 0.9611
# Epoch 65: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1148 - accuracy: 0.9611 - val_loss: 1.1221 - val_accuracy: 0.8496
# Epoch 66/100
# 1401/1407 [============================>.] - ETA: 0s - loss: 0.1142 - accuracy: 0.9611
# Epoch 66: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1141 - accuracy: 0.9611 - val_loss: 1.0634 - val_accuracy: 0.8513
# Epoch 67/100
# 1401/1407 [============================>.] - ETA: 0s - loss: 0.1141 - accuracy: 0.9614
# Epoch 67: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1141 - accuracy: 0.9614 - val_loss: 1.1283 - val_accuracy: 0.8504
# Epoch 68/100
# 1403/1407 [============================>.] - ETA: 0s - loss: 0.1147 - accuracy: 0.9609
# Epoch 68: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1149 - accuracy: 0.9608 - val_loss: 1.1371 - val_accuracy: 0.8503
# Epoch 69/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 0.1122 - accuracy: 0.9619
# Epoch 69: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1124 - accuracy: 0.9618 - val_loss: 1.0863 - val_accuracy: 0.8492
# Epoch 70/100
# 1401/1407 [============================>.] - ETA: 0s - loss: 0.1107 - accuracy: 0.9620
# Epoch 70: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1107 - accuracy: 0.9620 - val_loss: 1.0948 - val_accuracy: 0.8530
# Epoch 71/100
# 1403/1407 [============================>.] - ETA: 0s - loss: 0.1132 - accuracy: 0.9623
# Epoch 71: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1131 - accuracy: 0.9624 - val_loss: 1.1020 - val_accuracy: 0.8515
# Epoch 72/100
# 1402/1407 [============================>.] - ETA: 0s - loss: 0.1101 - accuracy: 0.9624
# Epoch 72: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1101 - accuracy: 0.9624 - val_loss: 1.1131 - val_accuracy: 0.8500
# Epoch 73/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.1111 - accuracy: 0.9623
# Epoch 73: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 10ms/step - loss: 0.1111 - accuracy: 0.9623 - val_loss: 1.1133 - val_accuracy: 0.8514
# Epoch 74/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.1097 - accuracy: 0.9628
# Epoch 74: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1098 - accuracy: 0.9628 - val_loss: 1.0683 - val_accuracy: 0.8539
# Epoch 75/100
# 1407/1407 [==============================] - ETA: 0s - loss: 0.1114 - accuracy: 0.9621
# Epoch 75: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1114 - accuracy: 0.9621 - val_loss: 1.2254 - val_accuracy: 0.8443
# Epoch 76/100
# 1405/1407 [============================>.] - ETA: 0s - loss: 0.1109 - accuracy: 0.9624
# Epoch 76: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1109 - accuracy: 0.9624 - val_loss: 1.0578 - val_accuracy: 0.8562
# Epoch 77/100
# 1405/1407 [============================>.] - ETA: 0s - loss: 0.1088 - accuracy: 0.9634
# Epoch 77: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1088 - accuracy: 0.9634 - val_loss: 1.1924 - val_accuracy: 0.8524
# Epoch 78/100
# 1403/1407 [============================>.] - ETA: 0s - loss: 0.1093 - accuracy: 0.9630
# Epoch 78: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1093 - accuracy: 0.9630 - val_loss: 1.1345 - val_accuracy: 0.8493
# Epoch 79/100
# 1403/1407 [============================>.] - ETA: 0s - loss: 0.1075 - accuracy: 0.9635
# Epoch 79: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1075 - accuracy: 0.9635 - val_loss: 1.1805 - val_accuracy: 0.8534
# Epoch 80/100
# 1405/1407 [============================>.] - ETA: 0s - loss: 0.1080 - accuracy: 0.9634
# Epoch 80: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1080 - accuracy: 0.9633 - val_loss: 1.2510 - val_accuracy: 0.8498
# Epoch 81/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.1088 - accuracy: 0.9636
# Epoch 81: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1088 - accuracy: 0.9636 - val_loss: 1.2224 - val_accuracy: 0.8489
# Epoch 82/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.1093 - accuracy: 0.9633
# Epoch 82: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1093 - accuracy: 0.9633 - val_loss: 1.1859 - val_accuracy: 0.8508
# Epoch 83/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 0.1070 - accuracy: 0.9637
# Epoch 83: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1070 - accuracy: 0.9637 - val_loss: 1.2271 - val_accuracy: 0.8497
# Epoch 84/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.1066 - accuracy: 0.9643
# Epoch 84: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1066 - accuracy: 0.9643 - val_loss: 1.1145 - val_accuracy: 0.8552
# Epoch 85/100
# 1405/1407 [============================>.] - ETA: 0s - loss: 0.1056 - accuracy: 0.9643
# Epoch 85: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1056 - accuracy: 0.9643 - val_loss: 1.1379 - val_accuracy: 0.8505
# Epoch 86/100
# 1407/1407 [==============================] - ETA: 0s - loss: 0.1073 - accuracy: 0.9643
# Epoch 86: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1073 - accuracy: 0.9643 - val_loss: 1.1989 - val_accuracy: 0.8498
# Epoch 87/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.1055 - accuracy: 0.9642
# Epoch 87: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1055 - accuracy: 0.9643 - val_loss: 1.1485 - val_accuracy: 0.8537
# Epoch 88/100
# 1401/1407 [============================>.] - ETA: 0s - loss: 0.1065 - accuracy: 0.9643
# Epoch 88: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1065 - accuracy: 0.9643 - val_loss: 1.1971 - val_accuracy: 0.8540
# Epoch 89/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 0.1035 - accuracy: 0.9648
# Epoch 89: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1035 - accuracy: 0.9648 - val_loss: 1.1932 - val_accuracy: 0.8567
# Epoch 90/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 0.1050 - accuracy: 0.9645
# Epoch 90: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1050 - accuracy: 0.9645 - val_loss: 1.1642 - val_accuracy: 0.8576
# Epoch 91/100
# 1405/1407 [============================>.] - ETA: 0s - loss: 0.1040 - accuracy: 0.9647
# Epoch 91: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1040 - accuracy: 0.9646 - val_loss: 1.2541 - val_accuracy: 0.8537
# Epoch 92/100
# 1403/1407 [============================>.] - ETA: 0s - loss: 0.1041 - accuracy: 0.9645
# Epoch 92: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1042 - accuracy: 0.9645 - val_loss: 1.1714 - val_accuracy: 0.8558
# Epoch 93/100
# 1401/1407 [============================>.] - ETA: 0s - loss: 0.1047 - accuracy: 0.9650
# Epoch 93: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1047 - accuracy: 0.9650 - val_loss: 1.1859 - val_accuracy: 0.8540
# Epoch 94/100
# 1403/1407 [============================>.] - ETA: 0s - loss: 0.1016 - accuracy: 0.9652
# Epoch 94: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1016 - accuracy: 0.9652 - val_loss: 1.0983 - val_accuracy: 0.8597
# Epoch 95/100
# 1403/1407 [============================>.] - ETA: 0s - loss: 0.1027 - accuracy: 0.9655
# Epoch 95: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 14s 10ms/step - loss: 0.1027 - accuracy: 0.9655 - val_loss: 1.0864 - val_accuracy: 0.8548
# Epoch 96/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.1040 - accuracy: 0.9657
# Epoch 96: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1040 - accuracy: 0.9657 - val_loss: 1.1394 - val_accuracy: 0.8510
# Epoch 97/100
# 1407/1407 [==============================] - ETA: 0s - loss: 0.1030 - accuracy: 0.9655
# Epoch 97: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1030 - accuracy: 0.9655 - val_loss: 1.0652 - val_accuracy: 0.8549
# Epoch 98/100
# 1402/1407 [============================>.] - ETA: 0s - loss: 0.1022 - accuracy: 0.9659
# Epoch 98: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1021 - accuracy: 0.9659 - val_loss: 1.2584 - val_accuracy: 0.8521
# Epoch 99/100
# 1402/1407 [============================>.] - ETA: 0s - loss: 0.1016 - accuracy: 0.9657
# Epoch 99: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.1015 - accuracy: 0.9657 - val_loss: 1.2854 - val_accuracy: 0.8493
# Epoch 100/100
# 1405/1407 [============================>.] - ETA: 0s - loss: 0.1022 - accuracy: 0.9653
# Epoch 100: val_accuracy did not improve from 0.86198
# 1407/1407 [==============================] - 13s 10ms/step - loss: 0.1021 - accuracy: 0.9653 - val_loss: 1.1532 - val_accuracy: 0.8563
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 512)               401920
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 30)                3870
#
# =================================================================
# Total params: 570,014
# Trainable params: 570,014
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 학습 결과 시각화
gold.history.keys() # dictionary 형태로 이루어짐

history_dict = gold.history
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)
fig = plt.figure(figsize=(12, 6))

ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, loss, color='blue', label='train_loss')
ax1.plot(epochs, val_loss, color='red', label='val_loss')
ax1.set_title('Train and Validation Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.grid()
ax1.legend()

accuracy = history_dict['accuracy']
val_accuracy = history_dict['val_accuracy']

ax2 = fig.add_subplot(1,2,2)
ax2.plot(epochs, accuracy, color='blue', label='train_accuracy')
ax2.plot(epochs, val_accuracy, color='red', label='val_accuracy')
ax2.set_title('Train and Validation accuracy')
ax2.set_xLabel('Epochs')
ax2.set_ylabel('Loss')
ax2.grid()
ax2.legend()

plt.show()

# %% [markdown]
# # **4. 모델 저장**

# %%
save_path = '/content/'
team_name = 'team10'

# 트레이닝된 전체 모델을 저장합니다.
model.save(save_path +  'model_entire_'+ team_name + '.h5')

# %% [markdown]
# # **5. 모델 로드 및 평가**

# %%
save_path = '/content/'
team_name = 'team10'

model = keras.models.load_model(save_path + 'model_entire_' + team_name + '.h5')

model.evaluate(x_test_after, y_test)
# Out:
# 1250/1250 [==============================] - 3s 2ms/step - loss: 1.9506 - accuracy: 0.8723
# [1.950639009475708, 0.8722500205039978]
