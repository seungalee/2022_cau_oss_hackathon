# %% [markdown]
# <a href="https://colab.research.google.com/github/seungalee/2022_cau_oss_hackathon/blob/main/hackathon_team10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **0. 해커톤 진행 주의사항**
#
# **1)  개발 관련 주의사항**
# *   [1. 초기 환경 설정]은 절대 수정하지 말 것
# *   모든 구현은 [2. 데이터 전처리] 및 [3.모델 생성]에서만 진행
# *   [4. 모델 저장]에서 team_name 변수 변경 (예.`team_name = 'team01'`)
#  *    트레이닝 중간에 checkpoint를 활용하여 모델을 저장한 경우에도 파일 이름 양식 통일 필수
# *   Colab 사용중 실수로 데이터 손실이 발생할 수도 있으니 중간 결과값을 github에 업로드
#  *    "런타임 -> 런타임 연결 해제 및 삭제"은 절대 누르지 말 것 (저장한 모델 데이터가 모두 삭제됨)
#  *    "런타임 -> 런타임 다시시작"은 클라우드 스토리지에 저장된 모델은 유지됨
# *   효율적인 구현 및 테스팅을 위해 GPU 가속 기능 활성화
#  *    "런타임 -> 런타임 유형변경 -> 하드웨어 가속기 -> GPU 설정"
# *   주석을 최대한 자세히 작성
# *   Keras API 관련하여 [Keras Documentation](https://keras.io/) 참조
#
# **2) 제출 관련 주의사항**
# *  제출물
#  *  소스코드 (hackathon_teamXX.ipynb)
#  *  컴파일된 모델 파일 (model_entire_teamXX.h5)
#  *  모델 발표 자료
# * 제출 기한: **오후 6시 (단, 발표자료는 12시)**
# * 제출 방법: [GitHub README](https://github.com/cauosshackathonta/2022_cau_oss_hackathon/) 참조
#
#
# **3) 평가 관련 주의사항**
# *  모델 성능 = 테스트 데이터 셋 분류 정확도
#  *  model.evaluate(x_test, y_test)
# *  제출된 모델들의 테스트 데이터 셋 분류 정확도를 기준으로 수상작 결정
# *  수상 후보들에 대해서는 소스코드를 기반으로 모델 재검증
#
# **4) 수상 실격 사유**
# *  유사한 소스코드가 적발될 경우
# *  Pre-trained 모델을 사용한 경우 (transfer learning 포함)
# *  소스코드와 제출된 모델이 상이한 경우
# *  개발 관련 주의사항을 지키지 않은 경우
#  *  예: [초기 환경 설정]을 수정한 경우
# *  데이터 셋을 변조한 경우
#  *  예. 테스트 데이터 셋을 트레이닝 데이터 셋에 포함하여 모델 생성
# *  주석이 소스코드와 맞지 않거나 미비할 경우

# %% [markdown]
# # **1. 초기 환경 설정**

# %%
from __future__ import absolute_import, division, print_function, unicode_literals, unicode_literals

# tensorflow와 tf.keras 및 관련 라이브러리 임포트
import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np

from tensorflow import keras
from keras.utils import np_utils
from keras import datasets, layers, models

# 데이터셋 로드 (MNIST, fashion-MNIST, Kujushiji-MNIST, MNIST_corrupted (test only))
train_ds, test_ds = tfds.load('mnist', split=['train', 'test'], shuffle_files=False, batch_size=-1)

train_ds2, test_ds2 = tfds.load('fashion_mnist', split=['train', 'test'], shuffle_files=False, batch_size=-1)
train_ds2['label'] += 10;
test_ds2['label'] += 10;

train_ds3, test_ds3 = tfds.load('kmnist', split=['train', 'test'], shuffle_files=False, batch_size=-1)
train_ds3['label'] += 20;
test_ds3['label'] += 20;

test_ds4 = tfds.load('mnist_corrupted/zigzag', split='test', shuffle_files=False, batch_size=-1)

# 데이터셋 병합 (training: 180,000개, test: 40,000개)
x_train = np.append(np.append(train_ds['image'], train_ds2['image'], 0), train_ds3['image'], 0);
y_train = np.append(np.append(train_ds['label'], train_ds2['label'], 0), train_ds3['label'], 0);

x_test = np.append(np.append(np.append(test_ds['image'], test_ds2['image'], 0), test_ds3['image'], 0), test_ds4['image'], 0);
y_test = np.append(np.append(np.append(test_ds['label'], test_ds2['label'], 0), test_ds3['label'], 0), test_ds4['label'], 0);

# 분류를 위해 클래스 벡터를 바이너리 매트릭스로 변환
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)

# 총 클래스 개수: 30, 입력 데이터 구조: (28, 28, 1)
num_classes = y_train.shape[1]
input_shape = x_train.shape[1:]
print(num_classes, input_shape)
# Out:
# Downloading and preparing dataset 11.06 MiB (download: 11.06 MiB, generated: 21.00 MiB, total: 32.06 MiB) to ~/tensorflow_datasets/mnist/3.0.1...
# Dl Completed...:   0%|          | 0/4 [00:00<?, ? file/s]
# Dataset mnist downloaded and prepared to ~/tensorflow_datasets/mnist/3.0.1. Subsequent calls will reuse this data.
# Downloading and preparing dataset 29.45 MiB (download: 29.45 MiB, generated: 36.42 MiB, total: 65.87 MiB) to ~/tensorflow_datasets/fashion_mnist/3.0.1...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/60000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/fashion_mnist/3.0.1.incompleteS6ITTG/fashion_mnist-train.tfrecord*...:   0%|  …
# Generating test examples...:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/fashion_mnist/3.0.1.incompleteS6ITTG/fashion_mnist-test.tfrecord*...:   0%|   …
# Dataset fashion_mnist downloaded and prepared to ~/tensorflow_datasets/fashion_mnist/3.0.1. Subsequent calls will reuse this data.
# Downloading and preparing dataset 20.26 MiB (download: 20.26 MiB, generated: 31.76 MiB, total: 52.02 MiB) to ~/tensorflow_datasets/kmnist/3.0.1...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/60000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/kmnist/3.0.1.incompleteQ2D29V/kmnist-train.tfrecord*...:   0%|          | 0/60…
# Generating test examples...:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/kmnist/3.0.1.incompleteQ2D29V/kmnist-test.tfrecord*...:   0%|          | 0/100…
# Dataset kmnist downloaded and prepared to ~/tensorflow_datasets/kmnist/3.0.1. Subsequent calls will reuse this data.
# Downloading and preparing dataset 235.23 MiB (download: 235.23 MiB, generated: Unknown size, total: 235.23 MiB) to ~/tensorflow_datasets/mnist_corrupted/zigzag/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/60000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/mnist_corrupted/zigzag/1.0.0.incompleteQP3XAO/mnist_corrupted-train.tfrecord*.…
# Generating test examples...:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/mnist_corrupted/zigzag/1.0.0.incompleteQP3XAO/mnist_corrupted-test.tfrecord*..…
# Dataset mnist_corrupted downloaded and prepared to ~/tensorflow_datasets/mnist_corrupted/zigzag/1.0.0. Subsequent calls will reuse this data.
# 30 (28, 28, 1)

# %% [markdown]
# # **2. 데이터 전처리**

# %%
# 데이터 전처리 (예: normalization)
# 원본 데이터와 전처리 후 데이터를 구분하기 위해, 변수명 x_train_after, x_test_after를 변경하지 말 것
x_train_after = x_train / 255
x_test_after = x_test / 255

# %% [markdown]
# # **3. 모델 생성**

# %%
drop_rate = 0.3
# 순차 모델 생성 (가장 기본구조)
model = keras.Sequential()

# Flatten layer: 28 x 28 x 1 image를 1D vector input으로 변환
model.add(keras.layers.Flatten(input_shape=input_shape))

# 1st hidden layer: fully-connected layer
model.add(keras.layers.Dense(1024, activation=tf.nn.relu))
model.add(keras.layers.Dropout(drop_rate))



# 2nd hidden layer: fully-connected layer 
model.add(keras.layers.Dense(512, activation=tf.nn.relu))
model.add(keras.layers.Dropout(drop_rate))


# 3rd hidden layer: fully-connected layer 
model.add(keras.layers.Dense(256, activation=tf.nn.relu))
model.add(keras.layers.Dropout(drop_rate))


model.add(keras.layers.Dense(128, activation=tf.nn.relu))
model.add(keras.layers.Dropout(drop_rate))


# Output layer: fully-connected layer 
model.add(keras.layers.Dense(num_classes, activation=tf.nn.softmax))

# 모델 컴파일
# optimizer: 모델을 업데이트 하는 방식
# loss: 모델의 정확도를 판단하는 방식
# metrics: 트레이닝 및 테스팅 성능 모니터링을 위한 평가지표
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])


# 체크포인트 생성
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath='/content/checkpoint_entire_best.h5', monitor='val_accuracy', verbose=1, save_weight_only=False, save_best_only=True, mode='auto')

# 모델 트레이닝
# batch_size: 전체 데이터셋 중 몇개씩 학습시킬 것인지
# epoch: 학습에 전체 데이터셋이 총 몇번 이용될 것인지
# shuffle: 학습전에 트레이닝 데이터셋을 랜덤하게 섞을 것인지
# validation_data: 중간 성능 검증에 사용할 data set (x_test1_after, x_test2_after, 혹은 둘을 merge해서 사용)
model.fit(x_train_after, y_train, batch_size = 128, epochs = 100, shuffle=True, callbacks=[cp_callback], validation_data=(x_test_after, y_test))

model.summary()
# Out:
# Epoch 1/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 0.8090 - accuracy: 0.7584
# Epoch 1: val_accuracy improved from -inf to 0.82192, saving model to /content/checkpoint_entire_best.h5
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.8084 - accuracy: 0.7585 - val_loss: 0.6634 - val_accuracy: 0.8219
# Epoch 2/100
# 1401/1407 [============================>.] - ETA: 0s - loss: 0.3862 - accuracy: 0.8872
# Epoch 2: val_accuracy improved from 0.82192 to 0.83122, saving model to /content/checkpoint_entire_best.h5
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.3861 - accuracy: 0.8872 - val_loss: 0.6763 - val_accuracy: 0.8312
# Epoch 3/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 0.3198 - accuracy: 0.9060
# Epoch 3: val_accuracy improved from 0.83122 to 0.84377, saving model to /content/checkpoint_entire_best.h5
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.3197 - accuracy: 0.9060 - val_loss: 0.6967 - val_accuracy: 0.8438
# Epoch 4/100
# 1401/1407 [============================>.] - ETA: 0s - loss: 0.2871 - accuracy: 0.9147
# Epoch 4: val_accuracy improved from 0.84377 to 0.84562, saving model to /content/checkpoint_entire_best.h5
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.2870 - accuracy: 0.9147 - val_loss: 0.7172 - val_accuracy: 0.8456
# Epoch 5/100
# 1405/1407 [============================>.] - ETA: 0s - loss: 0.2669 - accuracy: 0.9201
# Epoch 5: val_accuracy did not improve from 0.84562
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.2669 - accuracy: 0.9201 - val_loss: 0.7527 - val_accuracy: 0.8419
# Epoch 6/100
# 1402/1407 [============================>.] - ETA: 0s - loss: 0.2482 - accuracy: 0.9253
# Epoch 6: val_accuracy did not improve from 0.84562
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.2482 - accuracy: 0.9253 - val_loss: 0.8316 - val_accuracy: 0.8441
# Epoch 7/100
# 1405/1407 [============================>.] - ETA: 0s - loss: 0.2350 - accuracy: 0.9284
# Epoch 7: val_accuracy improved from 0.84562 to 0.85650, saving model to /content/checkpoint_entire_best.h5
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.2351 - accuracy: 0.9283 - val_loss: 0.7850 - val_accuracy: 0.8565
# Epoch 8/100
# 1396/1407 [============================>.] - ETA: 0s - loss: 0.2286 - accuracy: 0.9309
# Epoch 8: val_accuracy did not improve from 0.85650
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.2287 - accuracy: 0.9308 - val_loss: 0.8470 - val_accuracy: 0.8550
# Epoch 9/100
# 1397/1407 [============================>.] - ETA: 0s - loss: 0.2161 - accuracy: 0.9338
# Epoch 9: val_accuracy did not improve from 0.85650
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.2160 - accuracy: 0.9338 - val_loss: 0.9512 - val_accuracy: 0.8479
# Epoch 10/100
# 1397/1407 [============================>.] - ETA: 0s - loss: 0.2106 - accuracy: 0.9339
# Epoch 10: val_accuracy did not improve from 0.85650
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.2106 - accuracy: 0.9339 - val_loss: 0.9551 - val_accuracy: 0.8499
# Epoch 11/100
# 1401/1407 [============================>.] - ETA: 0s - loss: 0.2054 - accuracy: 0.9372
# Epoch 11: val_accuracy improved from 0.85650 to 0.85950, saving model to /content/checkpoint_entire_best.h5
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.2054 - accuracy: 0.9372 - val_loss: 0.8226 - val_accuracy: 0.8595
# Epoch 12/100
# 1398/1407 [============================>.] - ETA: 0s - loss: 0.1975 - accuracy: 0.9386
# Epoch 12: val_accuracy did not improve from 0.85950
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1977 - accuracy: 0.9386 - val_loss: 0.9361 - val_accuracy: 0.8589
# Epoch 13/100
# 1396/1407 [============================>.] - ETA: 0s - loss: 0.1918 - accuracy: 0.9402
# Epoch 13: val_accuracy improved from 0.85950 to 0.86240, saving model to /content/checkpoint_entire_best.h5
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1919 - accuracy: 0.9402 - val_loss: 0.9019 - val_accuracy: 0.8624
# Epoch 14/100
# 1397/1407 [============================>.] - ETA: 0s - loss: 0.1917 - accuracy: 0.9411
# Epoch 14: val_accuracy did not improve from 0.86240
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1916 - accuracy: 0.9411 - val_loss: 0.8755 - val_accuracy: 0.8585
# Epoch 15/100
# 1396/1407 [============================>.] - ETA: 0s - loss: 0.1858 - accuracy: 0.9423
# Epoch 15: val_accuracy did not improve from 0.86240
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1857 - accuracy: 0.9423 - val_loss: 0.8628 - val_accuracy: 0.8592
# Epoch 16/100
# 1396/1407 [============================>.] - ETA: 0s - loss: 0.1828 - accuracy: 0.9434
# Epoch 16: val_accuracy improved from 0.86240 to 0.86580, saving model to /content/checkpoint_entire_best.h5
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1831 - accuracy: 0.9433 - val_loss: 0.8658 - val_accuracy: 0.8658
# Epoch 17/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.1773 - accuracy: 0.9440
# Epoch 17: val_accuracy did not improve from 0.86580
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1773 - accuracy: 0.9440 - val_loss: 1.1996 - val_accuracy: 0.8593
# Epoch 18/100
# 1403/1407 [============================>.] - ETA: 0s - loss: 0.1769 - accuracy: 0.9448
# Epoch 18: val_accuracy did not improve from 0.86580
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1769 - accuracy: 0.9448 - val_loss: 1.0299 - val_accuracy: 0.8594
# Epoch 19/100
# 1395/1407 [============================>.] - ETA: 0s - loss: 0.1736 - accuracy: 0.9460
# Epoch 19: val_accuracy did not improve from 0.86580
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1741 - accuracy: 0.9460 - val_loss: 1.0434 - val_accuracy: 0.8615
# Epoch 20/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 0.1707 - accuracy: 0.9468
# Epoch 20: val_accuracy did not improve from 0.86580
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1707 - accuracy: 0.9469 - val_loss: 1.2232 - val_accuracy: 0.8583
# Epoch 21/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.1695 - accuracy: 0.9468
# Epoch 21: val_accuracy did not improve from 0.86580
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1695 - accuracy: 0.9468 - val_loss: 1.0757 - val_accuracy: 0.8547
# Epoch 22/100
# 1395/1407 [============================>.] - ETA: 0s - loss: 0.1645 - accuracy: 0.9483
# Epoch 22: val_accuracy did not improve from 0.86580
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1645 - accuracy: 0.9483 - val_loss: 1.2217 - val_accuracy: 0.8581
# Epoch 23/100
# 1396/1407 [============================>.] - ETA: 0s - loss: 0.1682 - accuracy: 0.9479
# Epoch 23: val_accuracy did not improve from 0.86580
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1682 - accuracy: 0.9479 - val_loss: 1.1463 - val_accuracy: 0.8629
# Epoch 24/100
# 1405/1407 [============================>.] - ETA: 0s - loss: 0.1650 - accuracy: 0.9483
# Epoch 24: val_accuracy improved from 0.86580 to 0.86727, saving model to /content/checkpoint_entire_best.h5
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1650 - accuracy: 0.9483 - val_loss: 1.1132 - val_accuracy: 0.8673
# Epoch 25/100
# 1400/1407 [============================>.] - ETA: 0s - loss: 0.1595 - accuracy: 0.9500
# Epoch 25: val_accuracy did not improve from 0.86727
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1596 - accuracy: 0.9500 - val_loss: 1.0767 - val_accuracy: 0.8626
# Epoch 26/100
# 1395/1407 [============================>.] - ETA: 0s - loss: 0.1601 - accuracy: 0.9502
# Epoch 26: val_accuracy did not improve from 0.86727
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1598 - accuracy: 0.9503 - val_loss: 1.2404 - val_accuracy: 0.8603
# Epoch 27/100
# 1401/1407 [============================>.] - ETA: 0s - loss: 0.1607 - accuracy: 0.9497
# Epoch 27: val_accuracy did not improve from 0.86727
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1606 - accuracy: 0.9498 - val_loss: 1.1073 - val_accuracy: 0.8608
# Epoch 28/100
# 1399/1407 [============================>.] - ETA: 0s - loss: 0.1558 - accuracy: 0.9510
# Epoch 28: val_accuracy improved from 0.86727 to 0.87025, saving model to /content/checkpoint_entire_best.h5
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1557 - accuracy: 0.9510 - val_loss: 1.1069 - val_accuracy: 0.8702
# Epoch 29/100
# 1401/1407 [============================>.] - ETA: 0s - loss: 0.1540 - accuracy: 0.9512
# Epoch 29: val_accuracy did not improve from 0.87025
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1540 - accuracy: 0.9513 - val_loss: 1.2739 - val_accuracy: 0.8658
# Epoch 30/100
# 1405/1407 [============================>.] - ETA: 0s - loss: 0.1544 - accuracy: 0.9521
# Epoch 30: val_accuracy did not improve from 0.87025
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1544 - accuracy: 0.9521 - val_loss: 1.2567 - val_accuracy: 0.8644
# Epoch 31/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.1515 - accuracy: 0.9524
# Epoch 31: val_accuracy did not improve from 0.87025
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1516 - accuracy: 0.9524 - val_loss: 1.1223 - val_accuracy: 0.8643
# Epoch 32/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 0.1506 - accuracy: 0.9525
# Epoch 32: val_accuracy improved from 0.87025 to 0.87570, saving model to /content/checkpoint_entire_best.h5
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1506 - accuracy: 0.9525 - val_loss: 1.0327 - val_accuracy: 0.8757
# Epoch 33/100
# 1397/1407 [============================>.] - ETA: 0s - loss: 0.1549 - accuracy: 0.9523
# Epoch 33: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1549 - accuracy: 0.9523 - val_loss: 1.0665 - val_accuracy: 0.8655
# Epoch 34/100
# 1397/1407 [============================>.] - ETA: 0s - loss: 0.1485 - accuracy: 0.9533
# Epoch 34: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1486 - accuracy: 0.9533 - val_loss: 1.1466 - val_accuracy: 0.8734
# Epoch 35/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.1500 - accuracy: 0.9537
# Epoch 35: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1500 - accuracy: 0.9537 - val_loss: 1.1558 - val_accuracy: 0.8729
# Epoch 36/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 0.1494 - accuracy: 0.9535
# Epoch 36: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1494 - accuracy: 0.9535 - val_loss: 1.0444 - val_accuracy: 0.8714
# Epoch 37/100
# 1405/1407 [============================>.] - ETA: 0s - loss: 0.1498 - accuracy: 0.9534
# Epoch 37: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1498 - accuracy: 0.9534 - val_loss: 1.2846 - val_accuracy: 0.8610
# Epoch 38/100
# 1403/1407 [============================>.] - ETA: 0s - loss: 0.1481 - accuracy: 0.9539
# Epoch 38: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1481 - accuracy: 0.9539 - val_loss: 1.1862 - val_accuracy: 0.8678
# Epoch 39/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.1450 - accuracy: 0.9550
# Epoch 39: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1450 - accuracy: 0.9550 - val_loss: 1.2936 - val_accuracy: 0.8633
# Epoch 40/100
# 1397/1407 [============================>.] - ETA: 0s - loss: 0.1437 - accuracy: 0.9546
# Epoch 40: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1438 - accuracy: 0.9546 - val_loss: 1.1697 - val_accuracy: 0.8645
# Epoch 41/100
# 1403/1407 [============================>.] - ETA: 0s - loss: 0.1426 - accuracy: 0.9562
# Epoch 41: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1425 - accuracy: 0.9562 - val_loss: 1.2244 - val_accuracy: 0.8635
# Epoch 42/100
# 1398/1407 [============================>.] - ETA: 0s - loss: 0.1453 - accuracy: 0.9553
# Epoch 42: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1453 - accuracy: 0.9553 - val_loss: 1.1084 - val_accuracy: 0.8738
# Epoch 43/100
# 1394/1407 [============================>.] - ETA: 0s - loss: 0.1408 - accuracy: 0.9558
# Epoch 43: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1409 - accuracy: 0.9558 - val_loss: 1.2988 - val_accuracy: 0.8606
# Epoch 44/100
# 1397/1407 [============================>.] - ETA: 0s - loss: 0.1450 - accuracy: 0.9546
# Epoch 44: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1449 - accuracy: 0.9546 - val_loss: 1.5301 - val_accuracy: 0.8661
# Epoch 45/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 0.1442 - accuracy: 0.9556
# Epoch 45: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1442 - accuracy: 0.9556 - val_loss: 1.4511 - val_accuracy: 0.8592
# Epoch 46/100
# 1398/1407 [============================>.] - ETA: 0s - loss: 0.1389 - accuracy: 0.9566
# Epoch 46: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1388 - accuracy: 0.9567 - val_loss: 1.3736 - val_accuracy: 0.8684
# Epoch 47/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 0.1391 - accuracy: 0.9561
# Epoch 47: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1391 - accuracy: 0.9561 - val_loss: 1.2824 - val_accuracy: 0.8723
# Epoch 48/100
# 1403/1407 [============================>.] - ETA: 0s - loss: 0.1416 - accuracy: 0.9566
# Epoch 48: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1416 - accuracy: 0.9566 - val_loss: 1.3872 - val_accuracy: 0.8655
# Epoch 49/100
# 1407/1407 [==============================] - ETA: 0s - loss: 0.1387 - accuracy: 0.9567
# Epoch 49: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1387 - accuracy: 0.9567 - val_loss: 1.5981 - val_accuracy: 0.8676
# Epoch 50/100
# 1401/1407 [============================>.] - ETA: 0s - loss: 0.1386 - accuracy: 0.9573
# Epoch 50: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1386 - accuracy: 0.9573 - val_loss: 1.3396 - val_accuracy: 0.8682
# Epoch 51/100
# 1403/1407 [============================>.] - ETA: 0s - loss: 0.1392 - accuracy: 0.9571
# Epoch 51: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1392 - accuracy: 0.9571 - val_loss: 1.5131 - val_accuracy: 0.8612
# Epoch 52/100
# 1405/1407 [============================>.] - ETA: 0s - loss: 0.1383 - accuracy: 0.9574
# Epoch 52: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1382 - accuracy: 0.9574 - val_loss: 1.2813 - val_accuracy: 0.8708
# Epoch 53/100
# 1402/1407 [============================>.] - ETA: 0s - loss: 0.1356 - accuracy: 0.9582
# Epoch 53: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1356 - accuracy: 0.9582 - val_loss: 1.4310 - val_accuracy: 0.8644
# Epoch 54/100
# 1405/1407 [============================>.] - ETA: 0s - loss: 0.1353 - accuracy: 0.9575
# Epoch 54: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1354 - accuracy: 0.9575 - val_loss: 1.3331 - val_accuracy: 0.8686
# Epoch 55/100
# 1396/1407 [============================>.] - ETA: 0s - loss: 0.1326 - accuracy: 0.9585
# Epoch 55: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1327 - accuracy: 0.9585 - val_loss: 1.3933 - val_accuracy: 0.8714
# Epoch 56/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.1350 - accuracy: 0.9581
# Epoch 56: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1351 - accuracy: 0.9581 - val_loss: 1.2136 - val_accuracy: 0.8679
# Epoch 57/100
# 1394/1407 [============================>.] - ETA: 0s - loss: 0.1313 - accuracy: 0.9590
# Epoch 57: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1312 - accuracy: 0.9590 - val_loss: 1.3391 - val_accuracy: 0.8694
# Epoch 58/100
# 1401/1407 [============================>.] - ETA: 0s - loss: 0.1355 - accuracy: 0.9575
# Epoch 58: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1354 - accuracy: 0.9575 - val_loss: 1.4414 - val_accuracy: 0.8691
# Epoch 59/100
# 1400/1407 [============================>.] - ETA: 0s - loss: 0.1322 - accuracy: 0.9585
# Epoch 59: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1323 - accuracy: 0.9586 - val_loss: 1.6152 - val_accuracy: 0.8693
# Epoch 60/100
# 1402/1407 [============================>.] - ETA: 0s - loss: 0.1345 - accuracy: 0.9578
# Epoch 60: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1344 - accuracy: 0.9578 - val_loss: 1.4335 - val_accuracy: 0.8713
# Epoch 61/100
# 1401/1407 [============================>.] - ETA: 0s - loss: 0.1360 - accuracy: 0.9580
# Epoch 61: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1361 - accuracy: 0.9580 - val_loss: 1.4093 - val_accuracy: 0.8643
# Epoch 62/100
# 1398/1407 [============================>.] - ETA: 0s - loss: 0.1304 - accuracy: 0.9589
# Epoch 62: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1307 - accuracy: 0.9589 - val_loss: 1.4426 - val_accuracy: 0.8688
# Epoch 63/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 0.1291 - accuracy: 0.9597
# Epoch 63: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1290 - accuracy: 0.9597 - val_loss: 1.4746 - val_accuracy: 0.8720
# Epoch 64/100
# 1407/1407 [==============================] - ETA: 0s - loss: 0.1296 - accuracy: 0.9597
# Epoch 64: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1296 - accuracy: 0.9597 - val_loss: 1.5821 - val_accuracy: 0.8669
# Epoch 65/100
# 1395/1407 [============================>.] - ETA: 0s - loss: 0.1303 - accuracy: 0.9597
# Epoch 65: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1304 - accuracy: 0.9597 - val_loss: 1.7642 - val_accuracy: 0.8642
# Epoch 66/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.1293 - accuracy: 0.9599
# Epoch 66: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1292 - accuracy: 0.9599 - val_loss: 1.6513 - val_accuracy: 0.8650
# Epoch 67/100
# 1403/1407 [============================>.] - ETA: 0s - loss: 0.1312 - accuracy: 0.9592
# Epoch 67: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1312 - accuracy: 0.9592 - val_loss: 1.4266 - val_accuracy: 0.8714
# Epoch 68/100
# 1396/1407 [============================>.] - ETA: 0s - loss: 0.1290 - accuracy: 0.9599
# Epoch 68: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1290 - accuracy: 0.9599 - val_loss: 1.3862 - val_accuracy: 0.8676
# Epoch 69/100
# 1401/1407 [============================>.] - ETA: 0s - loss: 0.1290 - accuracy: 0.9598
# Epoch 69: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1290 - accuracy: 0.9597 - val_loss: 1.6268 - val_accuracy: 0.8657
# Epoch 70/100
# 1407/1407 [==============================] - ETA: 0s - loss: 0.1316 - accuracy: 0.9598
# Epoch 70: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 6s 5ms/step - loss: 0.1316 - accuracy: 0.9598 - val_loss: 1.4310 - val_accuracy: 0.8652
# Epoch 71/100
# 1397/1407 [============================>.] - ETA: 0s - loss: 0.1307 - accuracy: 0.9603
# Epoch 71: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1306 - accuracy: 0.9603 - val_loss: 1.3721 - val_accuracy: 0.8717
# Epoch 72/100
# 1399/1407 [============================>.] - ETA: 0s - loss: 0.1276 - accuracy: 0.9604
# Epoch 72: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1277 - accuracy: 0.9603 - val_loss: 1.6969 - val_accuracy: 0.8658
# Epoch 73/100
# 1403/1407 [============================>.] - ETA: 0s - loss: 0.1291 - accuracy: 0.9600
# Epoch 73: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1291 - accuracy: 0.9600 - val_loss: 1.4721 - val_accuracy: 0.8716
# Epoch 74/100
# 1405/1407 [============================>.] - ETA: 0s - loss: 0.1294 - accuracy: 0.9603
# Epoch 74: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1293 - accuracy: 0.9603 - val_loss: 1.5906 - val_accuracy: 0.8586
# Epoch 75/100
# 1402/1407 [============================>.] - ETA: 0s - loss: 0.1293 - accuracy: 0.9602
# Epoch 75: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1293 - accuracy: 0.9602 - val_loss: 1.7184 - val_accuracy: 0.8685
# Epoch 76/100
# 1400/1407 [============================>.] - ETA: 0s - loss: 0.1284 - accuracy: 0.9608
# Epoch 76: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.1286 - accuracy: 0.9608 - val_loss: 1.7477 - val_accuracy: 0.8593
# Epoch 77/100
# 1395/1407 [============================>.] - ETA: 0s - loss: 0.1252 - accuracy: 0.9609
# Epoch 77: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1250 - accuracy: 0.9609 - val_loss: 1.6110 - val_accuracy: 0.8688
# Epoch 78/100
# 1402/1407 [============================>.] - ETA: 0s - loss: 0.1290 - accuracy: 0.9608
# Epoch 78: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1291 - accuracy: 0.9608 - val_loss: 1.7521 - val_accuracy: 0.8660
# Epoch 79/100
# 1402/1407 [============================>.] - ETA: 0s - loss: 0.1268 - accuracy: 0.9605
# Epoch 79: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1268 - accuracy: 0.9606 - val_loss: 1.6156 - val_accuracy: 0.8687
# Epoch 80/100
# 1399/1407 [============================>.] - ETA: 0s - loss: 0.1272 - accuracy: 0.9610
# Epoch 80: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1270 - accuracy: 0.9611 - val_loss: 1.6846 - val_accuracy: 0.8665
# Epoch 81/100
# 1403/1407 [============================>.] - ETA: 0s - loss: 0.1281 - accuracy: 0.9607
# Epoch 81: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 6s 5ms/step - loss: 0.1281 - accuracy: 0.9606 - val_loss: 1.9265 - val_accuracy: 0.8651
# Epoch 82/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.1267 - accuracy: 0.9607
# Epoch 82: val_accuracy did not improve from 0.87570
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1267 - accuracy: 0.9607 - val_loss: 1.6962 - val_accuracy: 0.8691
# Epoch 83/100
# 1400/1407 [============================>.] - ETA: 0s - loss: 0.1266 - accuracy: 0.9615
# Epoch 83: val_accuracy improved from 0.87570 to 0.87773, saving model to /content/checkpoint_entire_best.h5
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1265 - accuracy: 0.9615 - val_loss: 1.4882 - val_accuracy: 0.8777
# Epoch 84/100
# 1407/1407 [==============================] - ETA: 0s - loss: 0.1241 - accuracy: 0.9615
# Epoch 84: val_accuracy did not improve from 0.87773
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1241 - accuracy: 0.9615 - val_loss: 1.7437 - val_accuracy: 0.8704
# Epoch 85/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 0.1237 - accuracy: 0.9617
# Epoch 85: val_accuracy did not improve from 0.87773
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1238 - accuracy: 0.9616 - val_loss: 1.9264 - val_accuracy: 0.8635
# Epoch 86/100
# 1405/1407 [============================>.] - ETA: 0s - loss: 0.1234 - accuracy: 0.9614
# Epoch 86: val_accuracy did not improve from 0.87773
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1234 - accuracy: 0.9614 - val_loss: 1.8311 - val_accuracy: 0.8615
# Epoch 87/100
# 1405/1407 [============================>.] - ETA: 0s - loss: 0.1231 - accuracy: 0.9620
# Epoch 87: val_accuracy did not improve from 0.87773
# 1407/1407 [==============================] - 6s 5ms/step - loss: 0.1231 - accuracy: 0.9620 - val_loss: 1.6363 - val_accuracy: 0.8703
# Epoch 88/100
# 1399/1407 [============================>.] - ETA: 0s - loss: 0.1218 - accuracy: 0.9617
# Epoch 88: val_accuracy did not improve from 0.87773
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1218 - accuracy: 0.9616 - val_loss: 1.9107 - val_accuracy: 0.8684
# Epoch 89/100
# 1397/1407 [============================>.] - ETA: 0s - loss: 0.1237 - accuracy: 0.9617
# Epoch 89: val_accuracy did not improve from 0.87773
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1235 - accuracy: 0.9617 - val_loss: 1.9026 - val_accuracy: 0.8696
# Epoch 90/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.1254 - accuracy: 0.9619
# Epoch 90: val_accuracy did not improve from 0.87773
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1254 - accuracy: 0.9619 - val_loss: 1.8756 - val_accuracy: 0.8669
# Epoch 91/100
# 1405/1407 [============================>.] - ETA: 0s - loss: 0.1248 - accuracy: 0.9620
# Epoch 91: val_accuracy did not improve from 0.87773
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.1248 - accuracy: 0.9620 - val_loss: 1.6142 - val_accuracy: 0.8688
# Epoch 92/100
# 1401/1407 [============================>.] - ETA: 0s - loss: 0.1220 - accuracy: 0.9621
# Epoch 92: val_accuracy did not improve from 0.87773
# 1407/1407 [==============================] - 6s 5ms/step - loss: 0.1220 - accuracy: 0.9621 - val_loss: 1.9432 - val_accuracy: 0.8646
# Epoch 93/100
# 1397/1407 [============================>.] - ETA: 0s - loss: 0.1225 - accuracy: 0.9623
# Epoch 93: val_accuracy did not improve from 0.87773
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1225 - accuracy: 0.9623 - val_loss: 1.5418 - val_accuracy: 0.8657
# Epoch 94/100
# 1404/1407 [============================>.] - ETA: 0s - loss: 0.1211 - accuracy: 0.9624
# Epoch 94: val_accuracy did not improve from 0.87773
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1210 - accuracy: 0.9624 - val_loss: 1.8345 - val_accuracy: 0.8719
# Epoch 95/100
# 1406/1407 [============================>.] - ETA: 0s - loss: 0.1223 - accuracy: 0.9629
# Epoch 95: val_accuracy did not improve from 0.87773
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1223 - accuracy: 0.9629 - val_loss: 1.6572 - val_accuracy: 0.8704
# Epoch 96/100
# 1407/1407 [==============================] - ETA: 0s - loss: 0.1189 - accuracy: 0.9632
# Epoch 96: val_accuracy did not improve from 0.87773
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1189 - accuracy: 0.9632 - val_loss: 1.8161 - val_accuracy: 0.8662
# Epoch 97/100
# 1403/1407 [============================>.] - ETA: 0s - loss: 0.1230 - accuracy: 0.9625
# Epoch 97: val_accuracy did not improve from 0.87773
# 1407/1407 [==============================] - 6s 5ms/step - loss: 0.1229 - accuracy: 0.9625 - val_loss: 1.6763 - val_accuracy: 0.8682
# Epoch 98/100
# 1401/1407 [============================>.] - ETA: 0s - loss: 0.1215 - accuracy: 0.9628
# Epoch 98: val_accuracy did not improve from 0.87773
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1215 - accuracy: 0.9628 - val_loss: 1.7683 - val_accuracy: 0.8624
# Epoch 99/100
# 1407/1407 [==============================] - ETA: 0s - loss: 0.1207 - accuracy: 0.9632
# Epoch 99: val_accuracy did not improve from 0.87773
# 1407/1407 [==============================] - 8s 5ms/step - loss: 0.1207 - accuracy: 0.9632 - val_loss: 1.7430 - val_accuracy: 0.8669
# Epoch 100/100
# 1395/1407 [============================>.] - ETA: 0s - loss: 0.1248 - accuracy: 0.9619
# Epoch 100: val_accuracy did not improve from 0.87773
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.1249 - accuracy: 0.9619 - val_loss: 1.6476 - val_accuracy: 0.8670
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_16 (Flatten)        (None, 784)               0
#
#  dense_64 (Dense)            (None, 1024)              803840
#
#  dropout_45 (Dropout)        (None, 1024)              0
#
#  dense_65 (Dense)            (None, 512)               524800
#
#  dropout_46 (Dropout)        (None, 512)               0
#
#  dense_66 (Dense)            (None, 256)               131328
#
#  dropout_47 (Dropout)        (None, 256)               0
#
#  dense_67 (Dense)            (None, 128)               32896
#
#  dropout_48 (Dropout)        (None, 128)               0
#
#  dense_68 (Dense)            (None, 64)                8256
#
#  dropout_49 (Dropout)        (None, 64)                0
#
#  dense_69 (Dense)            (None, 30)                1950
#
# =================================================================
# Total params: 1,503,070
# Trainable params: 1,503,070
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # **4. 모델 저장**

# %%
save_path = '/content/'
team_name = 'team10'

# 트레이닝된 전체 모델을 저장합니다.
model.save(save_path +  'model_entire_'+ team_name + '.h5')

# %% [markdown]
# # **5. 모델 로드 및 평가**

# %%
save_path = '/content/'
team_name = 'team10'

model = keras.models.load_model(save_path + 'model_entire_' + team_name + '.h5')

model.evaluate(x_test_after, y_test)
# Out:
# 1250/1250 [==============================] - 3s 2ms/step - loss: 1.9506 - accuracy: 0.8723
# [1.950639009475708, 0.8722500205039978]
